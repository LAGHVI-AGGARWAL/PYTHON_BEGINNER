# %% [markdown]
# <a href="https://colab.research.google.com/github/LAGHVI-AGGARWAL/PYTHON_BEGINNER/blob/main/data%20structures/Tuples.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# like list tuples are also ordered collection of data
# they are immutable (unchangeable)
# they are iterable
# can be heterogenous

# %%
planets = ["Mercury","Venus","earth","Mars","Jupiter","Saturn","Uranus","Neptune"]

# %%
type(planets)
# Out:
# list

# %%
planets[1] = 'laghvi'

# %%
planets
# the list value got changed
# Out:
# ['Mercury',
#  'laghvi',
#  'earth',
#  'Mars',
#  'Jupiter',
#  'Saturn',
#  'Uranus',
#  'Neptune']

# %%
# if we dont want to change the actual values stored as it is important, then we use tuples
# as tuples are immutable

# %%
t = ("Mercury","Venus","earth","Mars","Jupiter","Saturn","Uranus","Neptune")

# %%
type(t)
# Out:
# tuple

# %%
# indexing
print(t[0])

# slicing
t[2:4]
# Out:
# Mercury
# ('earth', 'Mars')

# %%
t[0]= 'laghvi'
# value could not be changed
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_2974/1735446587.py in <cell line: 0>()
# ----> 1 t[0]= 'laghvi'
#
# TypeError: 'tuple' object does not support item assignment

# %%
# can be hetergeneous
t1 = ('laghvi',23,56.7,True)

# %%
type(t1)
# Out:
# tuple

# %%
type(t1[0])
# Out:
# str

# %%
# creating a tuple

# %%
# empty tuple
# using curly brackets
# using tuple constructor

# %%
t = ()
print(t)
print(type(t))
# Out:
# ()
# <class 'tuple'>

# %%
t1 = tuple()
print(t1)
type(t1)
# Out:
# ()
# tuple

# %%
# non empty tuple

# %%
# tuple with a single element
t2 = (4)
type(t2)
# Out:
# int

# %%
# If you want to create a tuple with only one item, a simple (4)
# won't work—Python will think it's just an integer in parentheses.
#  You must include a trailing comma to define that there would be more elements that would come

# %%
t3 = (4,)
print(type(t))
t3
# Out:
# <class 'tuple'>
# (4,)

# %%
t4 = tuple(123)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_2974/3888409335.py in <cell line: 0>()
# ----> 1 t4 = tuple(123)
#
# TypeError: 'int' object is not iterable

# %%
t4 = tuple('laghvi')
t4
# Out:
# ('l', 'a', 'g', 'h', 'v', 'i')

# %%
type(t4)
# Out:
# tuple

# %%
len(t4)
# Out:
# 6

# %%
t5 = ([1,2],[3,4])
type(t5)
# Out:
# tuple

# %%
print(t5)
len(t5)
# Out:
# ([1, 2], [3, 4])
# 2

# %%
type(t5[0])
# Out:
# list

# %%
# mutability in tuples

# %%
t1 = (1,2,3)

# %%
t[0]= 4
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_2974/3197977688.py in <cell line: 0>()
# ----> 1 t[0]= 4
#
# TypeError: 'tuple' object does not support item assignment

# %%
t1 = ([1,2,3,4],'laghvi')
t1
# Out:
# ([1, 2, 3, 4], 'laghvi')

# %%
t1[0]
# Out:
# [1, 2, 3, 4]

# %%
t1[0][2] = 7
# the value got changed because as we know that lists are mutable so the
# overall tuple is not changed in the process but the list is changed
# ie the memory address where the list was there that did not get changed as the
# lists are mutable and no new copy was made for changing the elemen
t1
# Out:
# ([1, 2, 7, 4], 'laghvi')

# %%
# unpacking in tuples
# Python allows you to "unpack" a tuple directly into variables.

# %%
a,b = 2,3
print(a,b)
# Out:
# 2 3

# %%
a = 2
b = 3
c = 4
d = 5
print(a,b,c,d)
# writing like thid we can instead use tuples
# Out:
# 2 3 4 5

# %%
t = (1,3,5,7,9)
a,b,c,r,y = t
print(a,r,y)
# Out:
# 1 7 9

# %%
# operations on tuples

# %%
# count method - used  to count the total no of occurences of an element in tuple
# if the element does not exist it will give 0 as the output

# %%
t1 = (1,4,6,7,3,8,0,1,4)
print(t1.count(1))
print(t1.count(4))
print(t1.count('laghvi'))
# Out:
# 2
# 2
# 0

# %%
# index - used to print the index of the first occurence of the element

# %%
print(t1.index(1))
print(t1.index(3))
# Out:
# 0
# 4

# %%
# iteration

# %%
len(t)
# Out:
# 5

# %%
for i in t:
  print(i)
# Out:
# 1
# 3
# 5
# 7
# 9

# %%
# concatenation (generally done using + and *)

# %%
t3 = t + t1

# %%
t3
# Out:
# (1, 3, 5, 7, 9, 1, 4, 6, 7, 3, 8, 0, 1, 4)

# %%
t3 = t1 * t1
# cannot multiply two tuples as need  to multiply with an integer value
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_9554/1902477441.py in <cell line: 0>()
# ----> 1 t3 = t1 * t1
#
# TypeError: can't multiply sequence by non-int of type 'tuple'

# %%
t4 = t1*2

# %%
t4
# Out:
# (1, 4, 6, 7, 3, 8, 0, 1, 4, 1, 4, 6, 7, 3, 8, 0, 1, 4)

# %%
t1*2
# Out:
# (1, 4, 6, 7, 3, 8, 0, 1, 4, 1, 4, 6, 7, 3, 8, 0, 1, 4)

# %%
t1
# here t1 remained the same even after concatenating it with 2
# When you do t2 * 2, Python is not creating copies of the objects inside the tuple.
# It is just creating a new tuple that holds duplicate pointers to the same memory addresses.
# Out:
# (1, 4, 6, 7, 3, 8, 0, 1, 4)
